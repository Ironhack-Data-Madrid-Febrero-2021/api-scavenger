# %%
import requests
import json
# !pip3 install python-dotenv
import os
from dotenv import load_dotenv
load_dotenv()
import pandas as pd

# %% [markdown]
# ## Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain `.scavengerhunt` and they are scattered in different directories of this repo. The secret files are named from `.0001.scavengerhunt` to `.0024.scavengerhunt`. They are scattered randomly throughout this repo. You need to **search for these files by calling the Github API**, not searching the local files on your computer.

# %%
url = 'https://github.com/ironhack-datalabs/scavenger'

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
print(response2.headers)
# Out:
# {'Server': 'GitHub.com', 'Date': 'Sun, 28 Mar 2021 07:36:32 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Vary': 'X-PJAX, Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"049685e9c7c5c8f2b7ad4412e2cbd43b"', 'Cache-Control': 'max-age=0, private, must-revalidate', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'no-referrer-when-downgrade', 'Expect-CT': 'max-age=2592000, report-uri="https://api.github.com/_private/browser/errors"', 'Content-Security-Policy': "default-src 'none'; base-uri 'self'; block-all-mixed-content; connect-src 'self' uploads.github.com www.githubstatus.com collector.githubapp.com api.github.com github-cloud.s3.amazonaws.com github-production-repository-file-5c1aeb.s3.amazonaws.com github-production-upload-manifest-file-7fdce7.s3.amazonaws.com github-production-user-asset-6210df.s3.amazonaws.com cdn.optimizely.com logx
# ...

# %%
url = 'https://github.com/ironhack-datalabs/scavenger'
api_key=os.getenv("token")
headers = {'Content-Type': 'text/html', "Autorizacion":f"token {api_key}"}

response = requests.get(url, headers=headers)
print(response)
#print(response.text)
# Out:
# <Response [200]>

# %%
jokes=response.json()['.scavengerhunt']['.0001.scavengerhunt'][0]
print(jokes)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-56-b1851e85b554> in <module>
# ----> 1 jokes=response.json()['.scavengerhunt']['.0001.scavengerhunt'][0]
#       2 print(jokes)
#
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     898                     # used.
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#     902     @property
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ...

# %%
url = 'https://github.com/ironhack-datalabs/scavenger'
api_key=os.getenv("token")
headers = {'Contents': '.0001.scavengerhunt',"Autorizacion":f"token {api_key}"}

response = requests.get(url, headers=headers)
print(response)
print(response.text)
string_content = response.Content.ReadAsStringAsync('0001.scavengerhunt').Result
# Out:
# <Response [200]>
#
#
#
#
#
#
# <!DOCTYPE html>
# <html lang="en" >
#   <head>
#     <meta charset="utf-8">
#   <link rel="dns-prefetch" href="https://github.githubassets.com">
#   <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">
#   <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">
#
#
#
#   <link crossorigin="anonymous" media="all" integrity="sha512-+D6Fy+EweT791upBwWDwZQxdKdpY58/tEdY1xnOvq7urHPMZe2ZtMhRmzWUL6+Dknj2BwHdlVvxPHDB6ep7wQQ==" rel="stylesheet" href="https://github.githubassets.com/assets/frameworks-f83e85cbe130793efdd6ea41c160f065.css" />
#   <link crossorigin="anonymous" media="all" integrity="sha512-B+uagPXLI8XoStGPc9DrQ9xVWfBS0VvAKvYTQopaizdxo8T46TCtAVE9sY15FQ0kseA1LB3V5GKklDGuwjqCHg==" rel="stylesheet" href="https://github.githubassets.com/assets/site-07eb9a80f5cb23c5e84ad18f73d0eb43.css" />
# ...

# %%
import requests
r = requests.get('https://github.com/ironhack-datalabs/scavenger')

with open('.scavengerhunt','w') as fd:
    fd.write(r.content)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-f4e82fb8e834> in <module>
#       3
#       4 with open('.scavengerhunt','w') as fd:
# ----> 5     fd.write(r.content)
#       6
#
# TypeError: write() argument must be str, not bytes

# %%
url = 'https://github.com/ironhack-datalabs/scavenger'
file = {"myfile":open('.scavengerhunt','rb')}
#Upload File
response = requests.post(url, files=file)
response
# Out:
# <Response [403]>

# %%
headers = {url,"Autorizacion":f"token {api_key}"}
response = requests.post("https://github.com/ironhack-datalabs/scavenger",)
response.raise_for_status()
# Out:
#   File "<ipython-input-80-c4c459fa9819>", line 1
#     headers = {url,"Autorizacion":f"token {api_key}"}
#                                  ^
# SyntaxError: invalid syntax

# %%
response.raise_for_status() # ensure we notice bad responses
file = open('scavengerhunt', "w")
file.read(response.text)
file.close()

# %%
parameters={"Athorization": f"token{api_key}", 'Content': '.0001.scavengerhunt'}

# %%
response = requests.get(url, params=parameters)
jokes=response.json()['contents']['0001.scavengerhunt'][0]

print(jokes)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-36-f86a8a62998e> in <module>
#       1 response = requests.get(url, params=parameters)
#       2
# ----> 3 jokes=response.json()['contents']['0001.scavengerhunt'][0]
#       4
#       5 print(jokes)
#
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     898                     # used.
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#     902     @property
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
# ...
